# %% [markdown]
# <a href="https://colab.research.google.com/github/lui1zz/Greenteam/blob/main/Atividade1_Luiz_Fogaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🐧 Exercícios de SQL para Iniciantes com Pinguins! 🐧
# Sejam bem-vindos galera do time do verde!!! Este notebook é uma atividade para vocês darem os primeiros passos no SQL
#
# Antes de mais nada precisamos elucidar alguns conceitos que talvez que esteja começando do zero tenha noção. É importante que vocês busquem entender os conceitos e diferença entre:
# - IDE x IDLE
# - O que é uma linguagem compilada
# - O que é uma linguagem interpretada (esse conceito é importante para entender como o IDLE funciona)
# - Google Colab x IDE (pycharm, vscode e etc) quando vou usar cada uma dessas
# - O que é um SGDB (importante saber a diferença entre mySQL e SQL)
#
# Deixo aqui alguns links que podem ajudar a elucidar esses conceitos, infelizmente não achei nada em português para algumas coisas:
# - https://www.reddit.com/r/learnpython/comments/tkggd3/noob_question_ide_idle_repl_text_editor_shell/
# - https://www.quora.com/What-is-the-difference-between-IDE-and-IDLE
# - https://www.freecodecamp.org/portuguese/news/linguagens-de-programacao-interpretadas-x-compiladas-qual-e-a-diferenca/
# - https://dicasdeprogramacao.com.br/o-que-e-um-sgbd/
#
# Objetivo da atividade: Aprender a fazer consultas em uma tabela de dados sem precisar se conectar a um banco de dados complicado. Vamos carregar um arquivo CSV da internet e usar a biblioteca DuckDB para rodar comandos SQL diretamente nel (DuckDB irá emular um SGDB tradicional como mysql, postgresql e sql server).
#
# Dataset: Vamos usar o "Palmer Penguins", um conjunto de dados sobre pinguins coletados em três ilhas na Antártida.
#
# Vamos começar!

# %%
# Primeiro, vamos garantir que temos as ferramentas certas
# O comando "!" permite executar comandos do terminal dentro do notebook
# pandas: a biblioteca mais popular para manipulação de dados em Python
# duckdb-engine: o "motor" que nos permite usar SQL em cima dos nossos dados
#   caso você se interesse em saber mais o que é o duckdb acesse: https://duckdb.org/

# !pip install pandas duckdb-engine
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# Agora que as bibliotecas estão instaladas, vamos importá-las para o nosso código.
# Assim, podemos usar as funções que elas oferecem.

import pandas as pd
import duckdb

print("Bibliotecas importadas com sucesso!")
# Out:
# Bibliotecas importadas com sucesso!

# %%
# Aqui está a variável com a fonte de dados que vamos usar. É um link direto para um arquivo CSV.
url_dados = 'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv'

# Vamos usar o pandas para ler o arquivo CSV a partir do link e carregá-lo em uma estrutura chamada DataFrame.
# Pense em um DataFrame como uma tabela ou uma planilha do Excel dentro do Python.
df_pinguins = pd.read_csv(url_dados)

# %%
# Vamos criar uma conexão com o DuckDB.
# O parâmetro ':memory:' significa que o banco de dados vai rodar inteiramente na memória RAM
con = duckdb.connect(database=':memory:')

# Agora, o passo mais importante: vamos registrar nosso DataFrame 'df_pinguins' como uma tabela SQL.
# A partir de agora, o DuckDB vai "enxergar" nosso DataFrame como uma tabela chamada 'pinguins'.
# É nesta tabela 'pinguins' que vamos fazer todas as nossas consultas SQL.
con.register('pinguins', df_pinguins)

print("Ambiente SQL pronto! A tabela 'pinguins' foi criada na memória.")
# Out:
# Ambiente SQL pronto! A tabela 'pinguins' foi criada na memória.

# %%
# Para facilitar nossa vida, vamos criar uma função que executa uma query SQL
# e já retorna o resultado formatado como uma bela tabela do pandas.
# Assim, não precisamos repetir o mesmo código várias vezes.

def executar_query(query_sql):
  """
  Recebe uma string com um comando SQL, executa no DuckDB e retorna um DataFrame do pandas.
  """
  return con.execute(query_sql).fetchdf()

print("Função auxiliar 'executar_query' criada com sucesso.")
# Out:
# Função auxiliar 'executar_query' criada com sucesso.

# %% [markdown]
# # Atividade 1
#
# Antes de mais nada, pedimos para que evite ao máximo o **USO DE IA** para responder as questões, isso porque o nosso aprendizado não é fixado quando usamos IA, queremos que vocês pesquisem, deem a volta ao mundo para apreender, porque só assim o conteúdo será fixado na sua cabeça.

# %%
# É sempre uma boa prática olhar as primeiras linhas dos seus dados para entender como eles são.

query_all = """
  SELECT * FROM pinguins LIMIT 10;
"""

print("Visualização geral:")
reesultado_all = executar_query(query_all)
display(reesultado_all)
# Out:
# Visualização geral:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN    None  2007
# ...

# %%
# Exercício 1: Mostre apenas as colunas de espécie, ilha e sexo dos pinguins, limitando a 10 resultados.

query_ex1 = """
  SELECT SPECIES, ISLAND, SEX FROM pinguins LIMIT 10;
"""

print("Resultado do Exercício 1:")
resultado_ex1 = executar_query(query_ex1)
display(resultado_ex1)
# Out:
# Resultado do Exercício 1:
#   species     island     sex
# 0  Adelie  Torgersen    male
# 1  Adelie  Torgersen  female
# 2  Adelie  Torgersen  female
# 3  Adelie  Torgersen    None
# 4  Adelie  Torgersen  female
# 5  Adelie  Torgersen    male
# 6  Adelie  Torgersen  female
# 7  Adelie  Torgersen    male
# 8  Adelie  Torgersen    None
# 9  Adelie  Torgersen    None

# %%
# Exercício 2: Mostre todos os dados dos pinguins da espécie "Adelie" que vivem na ilha "Torgersen".

query_ex2 = """
  SELECT *
  FROM pinguins
  WHERE species='Adelie' AND ISLAND='Torgersen';

"""

print("Resultado do Exercício 2:")
resultado_ex2 = executar_query(query_ex2)
display(resultado_ex2)
# Out:
# Resultado do Exercício 2:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
# Exercício 3: Conte quantos pinguins existem em cada uma das ilhas.

query_ex3 = """
  Select island, count(island) as Pinguins_por_ilha
  from pinguins
  group by island

"""

print("Resultado do Exercício 3:")
resultado_ex3 = executar_query(query_ex3)
display(resultado_ex3)
# Out:
# Resultado do Exercício 3:
#       island  Pinguins_por_ilha
# 0  Torgersen                 52
# 1     Biscoe                168
# 2      Dream                124

# %%
# Exercício 4: Calcule o peso médio (body_mass_g) dos pinguins para cada espécie.
# Ordene o resultado do maior peso médio para o menor.

query_ex4 = """
Select species, AVG(body_mass_g) as peso_medio
from pinguins
group by species
order by species

"""

print("Resultado do Exercício 4:")
resultado_ex4 = executar_query(query_ex4)
display(resultado_ex4)
# Out:
# Resultado do Exercício 4:
#      species   peso_medio
# 0     Adelie  3700.662252
# 1  Chinstrap  3733.088235
# 2     Gentoo  5076.016260

# %%
# Exercício 5 (Desafio): Encontre a espécie e a ilha do pinguim com o maior comprimento de bico (bill_length_mm).
# Dica: Você pode precisar usar ORDER BY e LIMIT juntos para encontrar o "maior".

query_ex5 = """
Select species, island, Max(bill_length_mm) as Maior_comprimento_bico
from pinguins
group by species, island
order by Maior_comprimento_bico desc
LIMIT 1
"""

print("Resultado do Exercício 5 (Desafio):")
resultado_ex5 = executar_query(query_ex5)
display(resultado_ex5)
# Out:
# Resultado do Exercício 5 (Desafio):
#   species  island  Maior_comprimento_bico
# 0  Gentoo  Biscoe                    59.6

# %%
# Exercício 6: Encontre todos os pinguins machos ('male') que têm o comprimento da nadadeira (flipper_length_mm) maior ou igual a 220 mm.
# Mostre a espécie, a ilha e o comprimento da nadadeira.

query_ex6 = """
Select species, island, flipper_length_mm
from pinguins
where sex='male' and flipper_length_mm>219
"""

print("Resultado do Exercício 6:")
resultado_ex6 = executar_query(query_ex6)
display(resultado_ex6)
# Out:
# Resultado do Exercício 6:
#    species  island  flipper_length_mm
# 0   Gentoo  Biscoe              230.0
# 1   Gentoo  Biscoe              221.0
# 2   Gentoo  Biscoe              222.0
# 3   Gentoo  Biscoe              220.0
# 4   Gentoo  Biscoe              222.0
# 5   Gentoo  Biscoe              230.0
# 6   Gentoo  Biscoe              220.0
# 7   Gentoo  Biscoe              225.0
# 8   Gentoo  Biscoe              222.0
# 9   Gentoo  Biscoe              225.0
# 10  Gentoo  Biscoe              220.0
# 11  Gentoo  Biscoe              225.0
# 12  Gentoo  Biscoe              220.0
# 13  Gentoo  Biscoe              220.0
# 14  Gentoo  Biscoe              224.0
# 15  Gentoo  Biscoe              221.0
# 16  Gentoo  Biscoe              231.0
# 17  Gentoo  Biscoe              230.0
# 18  Gentoo  Biscoe              229.0
# 19  Gentoo  Biscoe              223.0
# 20  Gentoo  Biscoe              221.0
# 21  Gentoo  Biscoe              221.0
# 22  Gentoo  Biscoe              230.0
# ...

# %%
# Exercício 7: Para cada sexo, qual é a média do comprimento do bico (bill_length_mm) e a média da profundidade do bico (bill_depth_mm)?
# Ignore os registros onde o sexo não está preenchido (é NULO).

query_ex7 = """
select sex, avg(bill_length_mm),avg(bill_depth_mm)
from pinguins
where sex is not null
group by sex;
"""

print("Resultado do Exercício 7:")
resultado_ex7 = executar_query(query_ex7)
display(resultado_ex7)
# Out:
# Resultado do Exercício 7:
#       sex  avg(bill_length_mm)  avg(bill_depth_mm)
# 0  female            42.096970           16.425455
# 1    male            45.854762           17.891071

# %%
# Exercício 8: Quantos pinguins da espécie "Gentoo" foram registrados em cada ano?
# Ordene os resultados pelo ano.

query_ex8 = """
select year, count(species) as total
from pinguins
where species='Gentoo'
group by year


"""

print("Resultado do Exercício 8:")
resultado_ex8 = executar_query(query_ex8)
display(resultado_ex8)
# Out:
# Resultado do Exercício 8:
#    year  total
# 0  2007     34
# 1  2008     46
# 2  2009     44

# %%
# Exercício 9: Crie uma nova coluna chamada "classificacao_peso" para os pinguins da espécie "Chinstrap".
# Se o peso (body_mass_g) for maior que 4000, classifique como 'Pesado'.
# Se for menor ou igual a 4000, classifique como 'Leve'.
# Mostre a ilha, o peso e a nova coluna de classificação.

query_ex9 = """
select island, body_mass_g as peso, if(body_mass_g>4000,'PESADO', 'LEVE') as classificação
from pinguins
where species='Chinstrap'

"""

print("Resultado do Exercício 9:")
resultado_ex9 = executar_query(query_ex9)
display(resultado_ex9)
# Out:
# Resultado do Exercício 9:
#    island    peso classificação
# 0   Dream  3500.0          LEVE
# 1   Dream  3900.0          LEVE
# 2   Dream  3650.0          LEVE
# 3   Dream  3525.0          LEVE
# 4   Dream  3725.0          LEVE
# ..    ...     ...           ...
# 63  Dream  4000.0          LEVE
# 64  Dream  3400.0          LEVE
# 65  Dream  3775.0          LEVE
# 66  Dream  4100.0        PESADO
# 67  Dream  3775.0          LEVE
#
# [68 rows x 3 columns]

# %%
# Exercício 10 (Desafio Intermediário): Encontre o peso (body_mass_g) do pinguim mais pesado e do mais leve para cada combinação de ilha e espécie.
# Sua tabela final deve ter as colunas: ilha, especie, peso_maximo e peso_minimo.

query_ex10 = """
select island, species, max(body_mass_g) as peso_maximo, min(body_mass_g) as peso_minimo
from pinguins
group by island, species
"""

print("Resultado do Exercício 10:")
resultado_ex10 = executar_query(query_ex10)
display(resultado_ex10)
# Out:
# Resultado do Exercício 10:
#       island    species  peso_maximo  peso_minimo
# 0  Torgersen     Adelie       4700.0       2900.0
# 1     Biscoe     Adelie       4775.0       2850.0
# 2      Dream     Adelie       4650.0       2900.0
# 3     Biscoe     Gentoo       6300.0       3950.0
# 4      Dream  Chinstrap       4800.0       2700.0
